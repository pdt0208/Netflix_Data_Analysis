# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('Netflix_Dataset.csv')
df.head(10)
# Out:
#    Show_Id Category Title           Director  \
# 0        1  TV Show  0.03                NaN
# 1        2    Movie   0.3  Jorge Michel Grau
# 2        3    Movie     1       Gilbert Chan
# 3        4    Movie     9        Shane Acker
# 4        5    Movie    21     Robert Luketic
# 5        6  TV Show    46        Serdar Akar
# 6        7    Movie   122    Yasir Al Yasiri
# 7        8    Movie   187     Kevin Reynolds
# 8        9    Movie   706      Shravan Kumar
# 9       10    Movie  1920       Vikram Bhatt
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %%
pd.isnull(df).sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.describe()
# Out:
#            Show_Id
# count  7789.000000
# mean   3895.000000
# std    2248.634956
# min       1.000000
# 25%    1948.000000
# 50%    3895.000000
# 75%    5842.000000
# max    7789.000000

# %%
df.head(10)
# Out:
#    Show_Id Category Title           Director  \
# 0        1  TV Show  0.03                NaN
# 1        2    Movie   0.3  Jorge Michel Grau
# 2        3    Movie     1       Gilbert Chan
# 3        4    Movie     9        Shane Acker
# 4        5    Movie    21     Robert Luketic
# 5        6  TV Show    46        Serdar Akar
# 6        7    Movie   122    Yasir Al Yasiri
# 7        8    Movie   187     Kevin Reynolds
# 8        9    Movie   706      Shravan Kumar
# 9       10    Movie  1920       Vikram Bhatt
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Show_Id          int64
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   int64
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 669.5+ KB

# %%
df.head()
# Out:
#    Show_Id Category Title           Director  \
# 0        1  TV Show  0.03                NaN
# 1        2    Movie   0.3  Jorge Michel Grau
# 2        3    Movie     1       Gilbert Chan
# 3        4    Movie     9        Shane Acker
# 4        5    Movie    21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
df.shape
# Out:
# (7789, 11)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df[df['Title'].isin(['House of Cards'])]
# Out:
#       Show_Id Category           Title  \
# 2832     2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#      Release_Date Rating   Duration                     Type  \
# 2832     2-Nov-18  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
df[df['Title'].str.contains('House of Cards')]
# Out:
#       Show_Id Category           Title  \
# 2832     2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#      Release_Date Rating   Duration                     Type  \
# 2832     2-Nov-18  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
ax=sns.countplot(data=df, x='Category', palette='PuOr_r')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df.Release_Date
# Out:
# 0       14-Aug-20
# 1       23-Dec-16
# 2       20-Dec-18
# 3       16-Nov-17
# 4        1-Jan-20
#           ...
# 7784    19-Oct-20
# 7785     2-Mar-19
# 7786    25-Sep-20
# 7787    31-Oct-20
# 7788     1-Mar-20
# Name: Release_Date, Length: 7789, dtype: object

# %%
df.dtypes
# Out:
# Show_Id          int64
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df['Release_Date']=pd.to_datetime(df['Release_Date'])

# %%
df.head()
# Out:
#    Show_Id Category Title           Director  \
# 0        1  TV Show  0.03                NaN
# 1        2    Movie   0.3  Jorge Michel Grau
# 2        3    Movie     1       Gilbert Chan
# 3        4    Movie     9        Shane Acker
# 4        5    Movie    21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
# 4   2020-01-01  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
df.dtypes
# Out:
# Show_Id                  int64
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date    datetime64[ns]
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# dtype: object

# %%
#dt.year.value_counts() it counts the occurance of all the individual years in date column.

# %%
df['Release_Date'].dt.year.value_counts()
# Out:
# 2019.0    2154
# 2020.0    2010
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Release_Date, dtype: int64

# %%
df['Release_Date'].dt.year.value_counts().plot(kind='bar', color='green')
# Out:
# <AxesSubplot:>

# %%
df.groupby('Category').Category.count()
# Out:
# Category
# Movie      5379
# TV Show    2410
# Name: Category, dtype: int64

# %%
df['Year']=df['Release_Date'].dt.year

# %%
df.head()
# Out:
#    Show_Id Category Title           Director  \
# 0        1  TV Show  0.03                NaN
# 1        2    Movie   0.3  Jorge Michel Grau
# 2        3    Movie     1       Gilbert Chan
# 3        4    Movie     9        Shane Acker
# 4        5    Movie    21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
# 4   2020-01-01  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
df[(df['Category'] == 'Movie') & (df['Year'] == 2011)]
# Out:
#       Show_Id Category                                       Title  \
# 232       233    Movie                  A Stoning in Fulham County
# 308       309    Movie                    Adam: His Song Continues
# 2041     2042    Movie                               Even the Rain
# 2622     2623    Movie                                Hard Lessons
# 2962     2963    Movie                 In Defense of a Married Man
# 3221     3222    Movie                      Joseph: King of Dreams
# 5042     5043    Movie  Quiet Victory: The Charlie Wedemeyer Story
# 5833     5834    Movie                              Strange Voices
# 6847     6848    Movie                        The Ryan White Story
# 7151     7152    Movie                          Too Young the Hero
# 7232     7233    Movie                        Triumph of the Heart
# 7364     7365    Movie                            Unspeakable Acts
# 7416     7417    Movie                            Victim of Beauty
#
# ...

# %%
df[(df['Category'] == 'Movie') & (df['Type']=='Comedies') | (df['Country'] == 'United Kingdom')]
# Out:
#       Show_Id Category                   Title          Director  \
# 19         20    Movie                     '89               NaN
# 33         34    Movie            #realityhigh  Fernando Lebrija
# 58         59  TV Show             100% Hotter               NaN
# 72         73    Movie                17 Again       Burr Steers
# 82         83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...       ...      ...                     ...               ...
# 7670     7671  TV Show  World War II in Colour               NaN
# 7671     7672  TV Show  World's Busiest Cities               NaN
# 7688     7689    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725     7726    Movie            You Can Tutu       James Brown
# 7740     7741  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %%
data_new=df.dropna()

# %%
data_new.head()
# Out:
#    Show_Id Category Title           Director  \
# 1        2    Movie   0.3  Jorge Michel Grau
# 2        3    Movie     1       Gilbert Chan
# 3        4    Movie     9        Shane Acker
# 4        5    Movie    21     Robert Luketic
# 5        6  TV Show    46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#   Release_Date Rating  Duration  \
# 1   2016-12-23  TV-MA    93 min
# 2   2018-12-20      R    78 min
# 3   2017-11-16  PG-13    80 min
# 4   2020-01-01  PG-13   123 min
# 5   2017-07-01  TV-MA  1 Season
#
#                                                 Type  \
# ...

# %%
data_new.shape
# Out:
# (4811, 12)

# %%
data_new['Duration'].max()
# Out:
# '99 min'

# %%
 sns.violinplot(y='Year', data=data_new, color='Pink')
# Out:
# <AxesSubplot:ylabel='Year'>

# %%
data_new.head()
# Out:
#    Show_Id Category Title           Director  \
# 1        2    Movie   0.3  Jorge Michel Grau
# 2        3    Movie     1       Gilbert Chan
# 3        4    Movie     9        Shane Acker
# 4        5    Movie    21     Robert Luketic
# 5        6  TV Show    46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#   Release_Date Rating  Duration  \
# 1   2016-12-23  TV-MA    93 min
# 2   2018-12-20      R    78 min
# 3   2017-11-16  PG-13    80 min
# 4   2020-01-01  PG-13   123 min
# 5   2017-07-01  TV-MA  1 Season
#
#                                                 Type  \
# ...
